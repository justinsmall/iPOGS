# %% [markdown]
# # POP MOC(sigma 2) for 0.1-degree  -- SUNWAY cases
# **Input Data:** Monthly POP output timeseries files
# **Output Data:** Monthly mean AMOC sigma 2 timeseries
# **Description:** Computes MOC(sigma 2) offline from POP history files using simple xhistogram binning.
# **Date:** February 2023
# **Creator:** Steve Yeager (https://github.com/sgyeager/POP_MOC/blob/main/notebooks/pop_MOCsigma2_0.1deg.ipynb)
# **Updated:** Teagan King, February 2023
# **Note:** To use the MOCutils, a user will need to clone the POP_MOC repository (https://github.com/sgyeager/POP_MOC) and install MOCutils by going to the POP_MOC directory and running `pip install -e . --user`.
# It is also important to request enough memory for this notebook on a casper batch node; suggested allocation is 25GB.

# %%
# %load_ext autoreload
# %autoreload 2
import cftime
import copy
import dask
import glob
import matplotlib.pyplot as plt
# %matplotlib inline
from MOCutils import popmoc
import numpy as np  
import os
import pop_tools
import time
import xarray as xr 
from xhistogram.xarray import histogram

# %%
from dask.distributed import wait
dask.__version__
# Out:
# '2022.11.0'

# %%
pop_tools.__version__
# Out:
# '2023.3.0'

# %%
# Close out Dask Cluster and release workers:
# cluster.close()
# client.close()

# %%
def get_ClusterClient():
    import dask
    from dask_jobqueue import PBSCluster
    from dask.distributed import Client
    cluster = PBSCluster(
        cores=1,
        memory='20GiB',
        processes=1,
        queue='casper',
        resource_spec='select=1:ncpus=1:mem=20GB', 
        account='P93300313',
        walltime='06:00:00',
        interface='ib0',)

    dask.config.set({
        'distributed.dashboard.link':
        'https://jupyterhub.hpc.ucar.edu/stable/user/{USER}/proxy/{port}/status',
        "distributed.scheduler.worker-saturation": "1.0",
        'array.slicing.split_large_chunks': True
    })
    client = Client(cluster)
    return cluster, client

cluster, client = get_ClusterClient()
cluster.scale(50)
# Out:
# /glade/u/home/tking/.conda/envs/ipogs_from_steve/lib/python3.10/site-packages/distributed/node.py:183: UserWarning: Port 8787 is already in use.
# Perhaps you already have a cluster running?
# Hosting the HTTP server on port 39317 instead
#   warnings.warn(

# %%
client
# Out:
# <Client: 'tcp://10.12.206.54:32879' processes=0 threads=0, memory=0 B>

# %%
def time_set_midmonth(ds, time_name, deep=False):
    """
    Return copy of ds with values of ds[time_name] replaced with mid-month
    values (day=15) rather than end-month values.
    """
    year = ds[time_name].dt.year
    month = ds[time_name].dt.month
    year = xr.where(month==1,year-1,year)
    month = xr.where(month==1,12,month-1)
    nmonths = len(month)
    newtime = [cftime.DatetimeNoLeap(year[i], month[i], 15) for i in range(nmonths)]
    ds[time_name] = newtime
    return ds

# %% [markdown]
# # Get the required variables

# %%
fdir = '/glade/campaign/collections/cmip/CMIP6/iHESP/BRCP85/HR/B.E.13.BRCP85C5CN.ne120_t12.sehires38.003.sunway.CN_OFF/ocn/proc/tseries/month_1/'
fin = fdir + 'B.E.13.BRCP85C5CN.ne120_t12.sehires38.003.sunway.CN_OFF.pop.h.'
vvel_files = sorted(glob.glob(fin+'VVEL*.nc'))
wvel_files = sorted(glob.glob(fin+'WVEL*.nc'))
temp_files = sorted(glob.glob(fin+'TEMP*.nc'))
salt_files = sorted(glob.glob(fin+'SALT*.nc'))
uvel_files = sorted(glob.glob(fin+'UVEL*.nc'))

fgrd = '/glade/work/fredc/cesm/grid/POP/grid.3600x2400x62.nc'
ds_grid = xr.open_dataset(fgrd)

fmoc = '/glade/u/home/yeager/analysis/python/POP_MOC/moc_template.nc'
ds_moctemp = xr.open_dataset(fmoc)

## Define the MOC region mask:
rmask = ds_grid.REGION_MASK.drop(['ULONG','ULAT'])
rmaskglob = xr.where((rmask>0),1,0)
rmaskatl = xr.where((rmask>=6) & (rmask<=11),1,0)
rmaskmoc = xr.concat([rmaskglob,rmaskatl],dim=ds_moctemp.transport_regions)

# determine j=index of Atlantic region southern boundary
tmp = rmaskmoc.isel(transport_reg=1).sum('nlon')
atl_j = 0
j = 0
while (atl_j==0):
    if (tmp.isel(nlat=j).data>0):
        atl_j = j
    j += 1
atl_j = atl_j - 1

dz = ds_grid['dz'].persist() / 100.
kmt = ds_grid['KMT'].fillna(0).persist() 
print('got dz and kmt')
# Slow step (~12 mins)
dzt,dzu = popmoc.tx0p1v3_dztdzu(dz,kmt)
print('got dzt dzu')

# Compute sigma-2 field from POP model output
refz = 2000
refdep = xr.DataArray(refz)

# Grid Metrics
dxu = ds_grid['DXU']
dyu = ds_grid['DYU']
dxt = ds_grid['DXT']
dyt = ds_grid['DYT']

# %%
for n in range(len(vvel_files)):
    dsV = xr.open_mfdataset(vvel_files[n], chunks={'time':1,'nlat':100}, parallel=True)
    dsV = time_set_midmonth(dsV,'time')
    dsW = xr.open_mfdataset(wvel_files[n], chunks={'time':1,'nlat':100}, parallel=True)
    dsW = time_set_midmonth(dsW,'time')
    dsT = xr.open_mfdataset(temp_files[n], chunks={'time':1,'nlat':100}, parallel=True)
    dsT = time_set_midmonth(dsT,'time')
    dsS = xr.open_mfdataset(salt_files[n], chunks={'time':1,'nlat':100}, parallel=True)
    dsS = time_set_midmonth(dsS,'time')
    dsU = xr.open_mfdataset(uvel_files[n], chunks={'time':1,'nlat':100}, parallel=True)
    dsU = time_set_midmonth(dsU,'time')

    u_e_all = dsU['UVEL']
    u_e_all = u_e_all.where(u_e_all<1.e30,0)
    v_e_all = dsV['VVEL']
    v_e_all = v_e_all.where(v_e_all<1.e30,0)

    # Get model T & S
    salt_all = dsS['SALT']
    temp_all = dsT['TEMP']

    tlon = ds_grid.TLONG.drop(['ULONG','ULAT'])
    tlat = ds_grid.TLAT.drop(['ULONG','ULAT'])
    ulon = ds_grid.ULONG.drop(['TLONG','TLAT'])
    ulat = ds_grid.ULAT.drop(['TLONG','TLAT'])

    print("started MOC calculations {}".format(time.ctime()))
    v_e = v_e_all
    u_e = u_e_all
    salt = salt_all
    temp = temp_all

    # Sigma2 on model TLAT, TLONG
    sigma2_T = pop_tools.eos(salt=salt,temp=temp,depth=refdep) - 1000
    sigma2_T = sigma2_T.assign_attrs({'long_name':'Sigma referenced to {}m'.format(refz),'units':'kg/m^3'})

    # Define target sigma-2 vertical grid. Use a predefined target grid, or create your own!
    sigma_mid,sigma_edge = popmoc.sigma2_grid_86L()

    # Grid-oriented Volume FLuxes:
    u_e = (u_e*dyu*dzu/1.e4).assign_attrs({'units':'m^3/s'})
    v_e = (v_e*dxu*dzu/1.e4).assign_attrs({'units':'m^3/s'})

    # Convert u_e,v_e to C-grid fluxes
    u = 0.5*(u_e+u_e.shift(nlat=1))
    v = 0.5*(v_e+v_e.roll(nlon=1,roll_coords=False))

    # Volume fluxes in density-space. 
    iso_uflux = histogram(sigma2_T, bins=[sigma_edge.values],weights=u,dim=['z_t'],density=False)
    iso_uflux = iso_uflux.rename({'density_bin':'sigma'}).assign_coords({'sigma':sigma_mid})
    iso_vflux = histogram(sigma2_T, bins=[sigma_edge.values],weights=v,dim=['z_t'],density=False)
    iso_vflux = iso_vflux.rename({'density_bin':'sigma'}).assign_coords({'sigma':sigma_mid})

    # Compute Vertical Volume Flux from horizontal flux convergence
    wflux = popmoc.wflux(iso_uflux,iso_vflux,'sigma',sigma_edge,grid='C')
    wflux = wflux.assign_coords({'TLAT':tlat,'TLONG':tlon})

    # Compute MOC
    MOC = popmoc.compute_MOC(wflux,rmaskmoc,ds_moctemp.lat_aux_grid)
    MOC = MOC.transpose('time','transport_reg','sigma','lat_aux_grid')
    MOC = dask.optimize(MOC)[0]

    # add vflux at southern boundary of Atlantic domain
    tmp = iso_vflux*(rmaskmoc.shift(nlat=-1))
    tmp = tmp.isel(nlat=atl_j,transport_reg=1).sum('nlon')
    moc_s = -tmp.sortby('sigma',ascending=False).cumsum('sigma').sortby('sigma',ascending=True)/1.e6
    moc_s['sigma'] = sigma_edge.isel(sigma=slice(0,-1))
    MOC[{'transport_reg':1}] = MOC[{'transport_reg':1}] + moc_s

    # Save to netcdf
    MOCann = MOC.groupby('time.year').mean('time').rename({'year':'time'})
    dsout = MOCann.to_dataset()

    outdir = '/glade/scratch/tking/MOCsig/'
    fout = os.path.split(vvel_files[n])[-1].split('.')[:-3]
    fout.append('MOCsig')
    fout.append('{:04d}01-{:04d}12'.format(dsout.time.values[0],dsout.time.values[-1]))
    fout.append('nc')
    fout = '.'.join(fout)
    fout = os.path.join(outdir,fout)
    dsout.to_netcdf(fout,unlimited_dims='time')
    print("wrote {} at {}".format(fout, time.ctime()))
# Out:
# got dz and kmt
# got dzt dzu
# started MOC calculations Mon Mar 13 11:57:27 2023
# wrote /glade/scratch/tking/MOCsig/B.E.13.BRCP85C5CN.ne120_t12.sehires38.003.sunway.CN_OFF.pop.h.MOCsig.200601-200612.nc at Mon Mar 13 11:59:59 2023
# started MOC calculations Mon Mar 13 12:00:09 2023
# wrote /glade/scratch/tking/MOCsig/B.E.13.BRCP85C5CN.ne120_t12.sehires38.003.sunway.CN_OFF.pop.h.MOCsig.200701-200712.nc at Mon Mar 13 12:02:48 2023
# started MOC calculations Mon Mar 13 12:02:52 2023
# wrote /glade/scratch/tking/MOCsig/B.E.13.BRCP85C5CN.ne120_t12.sehires38.003.sunway.CN_OFF.pop.h.MOCsig.200801-200812.nc at Mon Mar 13 12:05:19 2023
# started MOC calculations Mon Mar 13 12:05:22 2023
# wrote /glade/scratch/tking/MOCsig/B.E.13.BRCP85C5CN.ne120_t12.sehires38.003.sunway.CN_OFF.pop.h.MOCsig.200901-200912.nc at Mon Mar 13 12:07:50 2023
# started MOC calculations Mon Mar 13 12:07:53 2023
# wrote /glade/scratch/tking/MOCsig/B.E.13.BRCP85C5CN.ne120_t12.sehires38.003.sunway.CN_OFF.pop.h.MOCsig.201001-201012.nc at Mon Mar 13 12:10:18 2023
# started MOC calculations Mon Mar 13 12:10:21 2023
# wrote /glade/scratch/tking/MOCsig/B.E.13.BRCP85C5CN.ne120_t12.sehires38.003.sunway.CN_OFF.pop.h.MOCsig.201101-201112.nc at Mon Mar 13 12:12:55 2023
# started MOC calculations Mon Mar 13 12:12:57 2023
# wrote /glade/scratch/tking/MOCsig/B.E.13.BRCP85C5CN.ne120_t12.sehires38.003.sunway.CN_OFF.pop.h.MOCsig.201201-201212.nc at Mon Mar 13 12:15:25 2023
# started MOC calculations Mon Mar 13 12:15:27 2023
# wrote /glade/scratch/tking/MOCsig/B.E.13.BRCP85C5CN.ne120_t12.sehires38.003.sunway.CN_OFF.pop.h.MOCsig.201301-201312.nc at Mon Mar 13 12:17:57 2023
# started MOC calculations Mon Mar 13 12:17:59 2023
# wrote /glade/scratch/tking/MOCsig/B.E.13.BRCP85C5CN.ne120_t12.sehires38.003.sunway.CN_OFF.pop.h.MOCsig.201401-201412.nc at Mon Mar 13 12:20:29 2023
# started MOC calculations Mon Mar 13 12:20:31 2023
# wrote /glade/scratch/tking/MOCsig/B.E.13.BRCP85C5CN.ne120_t12.sehires38.003.sunway.CN_OFF.pop.h.MOCsig.201501-201512.nc at Mon Mar 13 12:23:02 2023
# started MOC calculations Mon Mar 13 12:23:03 2023
# wrote /glade/scratch/tking/MOCsig/B.E.13.BRCP85C5CN.ne120_t12.sehires38.003.sunway.CN_OFF.pop.h.MOCsig.201601-201612.nc at Mon Mar 13 12:25:33 2023
# started MOC calculations Mon Mar 13 12:25:35 2023
# wrote /glade/scratch/tking/MOCsig/B.E.13.BRCP85C5CN.ne120_t12.sehires38.003.sunway.CN_OFF.pop.h.MOCsig.201701-201712.nc at Mon Mar 13 12:28:06 2023
# started MOC calculations Mon Mar 13 12:28:08 2023
# wrote /glade/scratch/tking/MOCsig/B.E.13.BRCP85C5CN.ne120_t12.sehires38.003.sunway.CN_OFF.pop.h.MOCsig.201801-201812.nc at Mon Mar 13 12:30:37 2023
# started MOC calculations Mon Mar 13 12:30:39 2023
# wrote /glade/scratch/tking/MOCsig/B.E.13.BRCP85C5CN.ne120_t12.sehires38.003.sunway.CN_OFF.pop.h.MOCsig.201901-201912.nc at Mon Mar 13 12:33:09 2023
# started MOC calculations Mon Mar 13 12:33:11 2023
# wrote /glade/scratch/tking/MOCsig/B.E.13.BRCP85C5CN.ne120_t12.sehires38.003.sunway.CN_OFF.pop.h.MOCsig.202001-202012.nc at Mon Mar 13 12:35:45 2023
# started MOC calculations Mon Mar 13 12:35:46 2023
# wrote /glade/scratch/tking/MOCsig/B.E.13.BRCP85C5CN.ne120_t12.sehires38.003.sunway.CN_OFF.pop.h.MOCsig.202101-202112.nc at Mon Mar 13 12:38:21 2023
# started MOC calculations Mon Mar 13 12:38:23 2023
# wrote /glade/scratch/tking/MOCsig/B.E.13.BRCP85C5CN.ne120_t12.sehires38.003.sunway.CN_OFF.pop.h.MOCsig.202201-202212.nc at Mon Mar 13 12:40:55 2023
# started MOC calculations Mon Mar 13 12:40:57 2023
# wrote /glade/scratch/tking/MOCsig/B.E.13.BRCP85C5CN.ne120_t12.sehires38.003.sunway.CN_OFF.pop.h.MOCsig.202301-202312.nc at Mon Mar 13 12:43:29 2023
# started MOC calculations Mon Mar 13 12:43:30 2023
# wrote /glade/scratch/tking/MOCsig/B.E.13.BRCP85C5CN.ne120_t12.sehires38.003.sunway.CN_OFF.pop.h.MOCsig.202401-202412.nc at Mon Mar 13 12:46:03 2023
# started MOC calculations Mon Mar 13 12:46:05 2023
# wrote /glade/scratch/tking/MOCsig/B.E.13.BRCP85C5CN.ne120_t12.sehires38.003.sunway.CN_OFF.pop.h.MOCsig.202501-202512.nc at Mon Mar 13 12:48:40 2023
# started MOC calculations Mon Mar 13 12:48:42 2023
# wrote /glade/scratch/tking/MOCsig/B.E.13.BRCP85C5CN.ne120_t12.sehires38.003.sunway.CN_OFF.pop.h.MOCsig.202601-202612.nc at Mon Mar 13 12:51:19 2023
# started MOC calculations Mon Mar 13 12:51:21 2023
# wrote /glade/scratch/tking/MOCsig/B.E.13.BRCP85C5CN.ne120_t12.sehires38.003.sunway.CN_OFF.pop.h.MOCsig.202701-202712.nc at Mon Mar 13 12:54:05 2023
# started MOC calculations Mon Mar 13 12:54:07 2023
# wrote /glade/scratch/tking/MOCsig/B.E.13.BRCP85C5CN.ne120_t12.sehires38.003.sunway.CN_OFF.pop.h.MOCsig.202801-202812.nc at Mon Mar 13 12:56:47 2023
# started MOC calculations Mon Mar 13 12:56:49 2023
# wrote /glade/scratch/tking/MOCsig/B.E.13.BRCP85C5CN.ne120_t12.sehires38.003.sunway.CN_OFF.pop.h.MOCsig.202901-202912.nc at Mon Mar 13 12:59:21 2023
# started MOC calculations Mon Mar 13 12:59:23 2023
# wrote /glade/scratch/tking/MOCsig/B.E.13.BRCP85C5CN.ne120_t12.sehires38.003.sunway.CN_OFF.pop.h.MOCsig.203001-203012.nc at Mon Mar 13 13:01:57 2023
# started MOC calculations Mon Mar 13 13:01:58 2023
# wrote /glade/scratch/tking/MOCsig/B.E.13.BRCP85C5CN.ne120_t12.sehires38.003.sunway.CN_OFF.pop.h.MOCsig.203101-203112.nc at Mon Mar 13 13:04:31 2023
# started MOC calculations Mon Mar 13 13:04:33 2023
# wrote /glade/scratch/tking/MOCsig/B.E.13.BRCP85C5CN.ne120_t12.sehires38.003.sunway.CN_OFF.pop.h.MOCsig.203201-203212.nc at Mon Mar 13 13:07:08 2023
# started MOC calculations Mon Mar 13 13:07:09 2023
# wrote /glade/scratch/tking/MOCsig/B.E.13.BRCP85C5CN.ne120_t12.sehires38.003.sunway.CN_OFF.pop.h.MOCsig.203301-203312.nc at Mon Mar 13 13:09:41 2023
# started MOC calculations Mon Mar 13 13:09:42 2023
# wrote /glade/scratch/tking/MOCsig/B.E.13.BRCP85C5CN.ne120_t12.sehires38.003.sunway.CN_OFF.pop.h.MOCsig.203401-203412.nc at Mon Mar 13 13:12:12 2023
# started MOC calculations Mon Mar 13 13:12:14 2023
# wrote /glade/scratch/tking/MOCsig/B.E.13.BRCP85C5CN.ne120_t12.sehires38.003.sunway.CN_OFF.pop.h.MOCsig.203501-203512.nc at Mon Mar 13 13:14:47 2023
# started MOC calculations Mon Mar 13 13:14:49 2023
# wrote /glade/scratch/tking/MOCsig/B.E.13.BRCP85C5CN.ne120_t12.sehires38.003.sunway.CN_OFF.pop.h.MOCsig.203601-203612.nc at Mon Mar 13 13:17:23 2023
# started MOC calculations Mon Mar 13 13:17:25 2023
# wrote /glade/scratch/tking/MOCsig/B.E.13.BRCP85C5CN.ne120_t12.sehires38.003.sunway.CN_OFF.pop.h.MOCsig.203701-203712.nc at Mon Mar 13 13:19:56 2023
# started MOC calculations Mon Mar 13 13:19:58 2023
# wrote /glade/scratch/tking/MOCsig/B.E.13.BRCP85C5CN.ne120_t12.sehires38.003.sunway.CN_OFF.pop.h.MOCsig.203801-203812.nc at Mon Mar 13 13:22:27 2023
# started MOC calculations Mon Mar 13 13:22:28 2023
# wrote /glade/scratch/tking/MOCsig/B.E.13.BRCP85C5CN.ne120_t12.sehires38.003.sunway.CN_OFF.pop.h.MOCsig.203901-203912.nc at Mon Mar 13 13:24:59 2023
# started MOC calculations Mon Mar 13 13:25:00 2023
# wrote /glade/scratch/tking/MOCsig/B.E.13.BRCP85C5CN.ne120_t12.sehires38.003.sunway.CN_OFF.pop.h.MOCsig.204001-204012.nc at Mon Mar 13 13:27:31 2023
# started MOC calculations Mon Mar 13 13:27:33 2023
# wrote /glade/scratch/tking/MOCsig/B.E.13.BRCP85C5CN.ne120_t12.sehires38.003.sunway.CN_OFF.pop.h.MOCsig.204101-204112.nc at Mon Mar 13 13:30:05 2023
# started MOC calculations Mon Mar 13 13:30:07 2023
# wrote /glade/scratch/tking/MOCsig/B.E.13.BRCP85C5CN.ne120_t12.sehires38.003.sunway.CN_OFF.pop.h.MOCsig.204201-204212.nc at Mon Mar 13 13:32:39 2023
# started MOC calculations Mon Mar 13 13:32:41 2023
# wrote /glade/scratch/tking/MOCsig/B.E.13.BRCP85C5CN.ne120_t12.sehires38.003.sunway.CN_OFF.pop.h.MOCsig.204301-204312.nc at Mon Mar 13 13:35:13 2023
# started MOC calculations Mon Mar 13 13:35:15 2023
# wrote /glade/scratch/tking/MOCsig/B.E.13.BRCP85C5CN.ne120_t12.sehires38.003.sunway.CN_OFF.pop.h.MOCsig.204401-204412.nc at Mon Mar 13 13:37:46 2023
# started MOC calculations Mon Mar 13 13:37:48 2023
# wrote /glade/scratch/tking/MOCsig/B.E.13.BRCP85C5CN.ne120_t12.sehires38.003.sunway.CN_OFF.pop.h.MOCsig.204501-204512.nc at Mon Mar 13 13:40:17 2023
# started MOC calculations Mon Mar 13 13:40:19 2023
# wrote /glade/scratch/tking/MOCsig/B.E.13.BRCP85C5CN.ne120_t12.sehires38.003.sunway.CN_OFF.pop.h.MOCsig.204601-204612.nc at Mon Mar 13 13:42:48 2023
# started MOC calculations Mon Mar 13 13:42:50 2023
# wrote /glade/scratch/tking/MOCsig/B.E.13.BRCP85C5CN.ne120_t12.sehires38.003.sunway.CN_OFF.pop.h.MOCsig.204701-204712.nc at Mon Mar 13 13:45:28 2023
# started MOC calculations Mon Mar 13 13:45:29 2023
# wrote /glade/scratch/tking/MOCsig/B.E.13.BRCP85C5CN.ne120_t12.sehires38.003.sunway.CN_OFF.pop.h.MOCsig.204801-204812.nc at Mon Mar 13 13:48:01 2023
# started MOC calculations Mon Mar 13 13:48:02 2023
# wrote /glade/scratch/tking/MOCsig/B.E.13.BRCP85C5CN.ne120_t12.sehires38.003.sunway.CN_OFF.pop.h.MOCsig.204901-204912.nc at Mon Mar 13 13:50:29 2023
# started MOC calculations Mon Mar 13 13:50:31 2023
# wrote /glade/scratch/tking/MOCsig/B.E.13.BRCP85C5CN.ne120_t12.sehires38.003.sunway.CN_OFF.pop.h.MOCsig.205001-205012.nc at Mon Mar 13 13:53:09 2023
# started MOC calculations Mon Mar 13 13:53:10 2023
# wrote /glade/scratch/tking/MOCsig/B.E.13.BRCP85C5CN.ne120_t12.sehires38.003.sunway.CN_OFF.pop.h.MOCsig.205101-205112.nc at Mon Mar 13 13:55:45 2023
# started MOC calculations Mon Mar 13 13:55:46 2023
# wrote /glade/scratch/tking/MOCsig/B.E.13.BRCP85C5CN.ne120_t12.sehires38.003.sunway.CN_OFF.pop.h.MOCsig.205201-205212.nc at Mon Mar 13 13:58:19 2023
# started MOC calculations Mon Mar 13 13:58:21 2023
# wrote /glade/scratch/tking/MOCsig/B.E.13.BRCP85C5CN.ne120_t12.sehires38.003.sunway.CN_OFF.pop.h.MOCsig.205301-205312.nc at Mon Mar 13 14:00:49 2023
# started MOC calculations Mon Mar 13 14:00:51 2023
# wrote /glade/scratch/tking/MOCsig/B.E.13.BRCP85C5CN.ne120_t12.sehires38.003.sunway.CN_OFF.pop.h.MOCsig.205401-205412.nc at Mon Mar 13 14:03:24 2023
# started MOC calculations Mon Mar 13 14:03:25 2023
# wrote /glade/scratch/tking/MOCsig/B.E.13.BRCP85C5CN.ne120_t12.sehires38.003.sunway.CN_OFF.pop.h.MOCsig.205501-205512.nc at Mon Mar 13 14:05:55 2023
# started MOC calculations Mon Mar 13 14:05:57 2023
# wrote /glade/scratch/tking/MOCsig/B.E.13.BRCP85C5CN.ne120_t12.sehires38.003.sunway.CN_OFF.pop.h.MOCsig.205601-205612.nc at Mon Mar 13 14:08:30 2023
# started MOC calculations Mon Mar 13 14:08:32 2023
# wrote /glade/scratch/tking/MOCsig/B.E.13.BRCP85C5CN.ne120_t12.sehires38.003.sunway.CN_OFF.pop.h.MOCsig.205701-205712.nc at Mon Mar 13 14:11:08 2023
# started MOC calculations Mon Mar 13 14:11:10 2023
# wrote /glade/scratch/tking/MOCsig/B.E.13.BRCP85C5CN.ne120_t12.sehires38.003.sunway.CN_OFF.pop.h.MOCsig.205801-205812.nc at Mon Mar 13 14:13:43 2023
# started MOC calculations Mon Mar 13 14:13:44 2023
# wrote /glade/scratch/tking/MOCsig/B.E.13.BRCP85C5CN.ne120_t12.sehires38.003.sunway.CN_OFF.pop.h.MOCsig.205901-205912.nc at Mon Mar 13 14:16:14 2023
# started MOC calculations Mon Mar 13 14:16:16 2023
# wrote /glade/scratch/tking/MOCsig/B.E.13.BRCP85C5CN.ne120_t12.sehires38.003.sunway.CN_OFF.pop.h.MOCsig.206001-206012.nc at Mon Mar 13 14:18:49 2023
# started MOC calculations Mon Mar 13 14:18:50 2023
# wrote /glade/scratch/tking/MOCsig/B.E.13.BRCP85C5CN.ne120_t12.sehires38.003.sunway.CN_OFF.pop.h.MOCsig.206101-206112.nc at Mon Mar 13 14:21:24 2023
# started MOC calculations Mon Mar 13 14:21:26 2023
# wrote /glade/scratch/tking/MOCsig/B.E.13.BRCP85C5CN.ne120_t12.sehires38.003.sunway.CN_OFF.pop.h.MOCsig.206201-206212.nc at Mon Mar 13 14:24:01 2023
# started MOC calculations Mon Mar 13 14:24:02 2023
# wrote /glade/scratch/tking/MOCsig/B.E.13.BRCP85C5CN.ne120_t12.sehires38.003.sunway.CN_OFF.pop.h.MOCsig.206301-206312.nc at Mon Mar 13 14:26:36 2023
# started MOC calculations Mon Mar 13 14:26:38 2023
# wrote /glade/scratch/tking/MOCsig/B.E.13.BRCP85C5CN.ne120_t12.sehires38.003.sunway.CN_OFF.pop.h.MOCsig.206401-206412.nc at Mon Mar 13 14:29:10 2023
# started MOC calculations Mon Mar 13 14:29:12 2023
# wrote /glade/scratch/tking/MOCsig/B.E.13.BRCP85C5CN.ne120_t12.sehires38.003.sunway.CN_OFF.pop.h.MOCsig.206501-206512.nc at Mon Mar 13 14:31:48 2023
# started MOC calculations Mon Mar 13 14:31:50 2023
# wrote /glade/scratch/tking/MOCsig/B.E.13.BRCP85C5CN.ne120_t12.sehires38.003.sunway.CN_OFF.pop.h.MOCsig.206601-206612.nc at Mon Mar 13 14:34:26 2023
# started MOC calculations Mon Mar 13 14:34:28 2023
# wrote /glade/scratch/tking/MOCsig/B.E.13.BRCP85C5CN.ne120_t12.sehires38.003.sunway.CN_OFF.pop.h.MOCsig.206701-206712.nc at Mon Mar 13 14:37:03 2023
# started MOC calculations Mon Mar 13 14:37:05 2023
# wrote /glade/scratch/tking/MOCsig/B.E.13.BRCP85C5CN.ne120_t12.sehires38.003.sunway.CN_OFF.pop.h.MOCsig.206801-206812.nc at Mon Mar 13 14:39:39 2023
# started MOC calculations Mon Mar 13 14:39:41 2023
# wrote /glade/scratch/tking/MOCsig/B.E.13.BRCP85C5CN.ne120_t12.sehires38.003.sunway.CN_OFF.pop.h.MOCsig.206901-206912.nc at Mon Mar 13 14:42:15 2023
# started MOC calculations Mon Mar 13 14:42:17 2023
# wrote /glade/scratch/tking/MOCsig/B.E.13.BRCP85C5CN.ne120_t12.sehires38.003.sunway.CN_OFF.pop.h.MOCsig.207001-207012.nc at Mon Mar 13 14:44:52 2023
# started MOC calculations Mon Mar 13 14:44:55 2023
# wrote /glade/scratch/tking/MOCsig/B.E.13.BRCP85C5CN.ne120_t12.sehires38.003.sunway.CN_OFF.pop.h.MOCsig.207101-207112.nc at Mon Mar 13 14:47:29 2023
# started MOC calculations Mon Mar 13 14:47:31 2023
# wrote /glade/scratch/tking/MOCsig/B.E.13.BRCP85C5CN.ne120_t12.sehires38.003.sunway.CN_OFF.pop.h.MOCsig.207201-207212.nc at Mon Mar 13 14:50:04 2023
# started MOC calculations Mon Mar 13 14:50:05 2023
# wrote /glade/scratch/tking/MOCsig/B.E.13.BRCP85C5CN.ne120_t12.sehires38.003.sunway.CN_OFF.pop.h.MOCsig.207301-207312.nc at Mon Mar 13 14:52:39 2023
# started MOC calculations Mon Mar 13 14:52:41 2023
# wrote /glade/scratch/tking/MOCsig/B.E.13.BRCP85C5CN.ne120_t12.sehires38.003.sunway.CN_OFF.pop.h.MOCsig.207401-207412.nc at Mon Mar 13 14:55:14 2023
# started MOC calculations Mon Mar 13 14:55:15 2023
# wrote /glade/scratch/tking/MOCsig/B.E.13.BRCP85C5CN.ne120_t12.sehires38.003.sunway.CN_OFF.pop.h.MOCsig.207501-207512.nc at Mon Mar 13 14:57:49 2023
# started MOC calculations Mon Mar 13 14:57:51 2023
# wrote /glade/scratch/tking/MOCsig/B.E.13.BRCP85C5CN.ne120_t12.sehires38.003.sunway.CN_OFF.pop.h.MOCsig.207601-207612.nc at Mon Mar 13 15:00:27 2023
# started MOC calculations Mon Mar 13 15:00:30 2023
# wrote /glade/scratch/tking/MOCsig/B.E.13.BRCP85C5CN.ne120_t12.sehires38.003.sunway.CN_OFF.pop.h.MOCsig.207701-207712.nc at Mon Mar 13 15:03:01 2023
# started MOC calculations Mon Mar 13 15:03:03 2023
# wrote /glade/scratch/tking/MOCsig/B.E.13.BRCP85C5CN.ne120_t12.sehires38.003.sunway.CN_OFF.pop.h.MOCsig.207801-207812.nc at Mon Mar 13 15:05:33 2023
# started MOC calculations Mon Mar 13 15:05:35 2023
# wrote /glade/scratch/tking/MOCsig/B.E.13.BRCP85C5CN.ne120_t12.sehires38.003.sunway.CN_OFF.pop.h.MOCsig.207901-207912.nc at Mon Mar 13 15:08:04 2023
# started MOC calculations Mon Mar 13 15:08:05 2023
# wrote /glade/scratch/tking/MOCsig/B.E.13.BRCP85C5CN.ne120_t12.sehires38.003.sunway.CN_OFF.pop.h.MOCsig.208001-208012.nc at Mon Mar 13 15:10:34 2023
# started MOC calculations Mon Mar 13 15:10:35 2023
# wrote /glade/scratch/tking/MOCsig/B.E.13.BRCP85C5CN.ne120_t12.sehires38.003.sunway.CN_OFF.pop.h.MOCsig.208101-208112.nc at Mon Mar 13 15:13:02 2023
# started MOC calculations Mon Mar 13 15:13:04 2023
# wrote /glade/scratch/tking/MOCsig/B.E.13.BRCP85C5CN.ne120_t12.sehires38.003.sunway.CN_OFF.pop.h.MOCsig.208201-208212.nc at Mon Mar 13 15:15:34 2023
# started MOC calculations Mon Mar 13 15:15:36 2023
# wrote /glade/scratch/tking/MOCsig/B.E.13.BRCP85C5CN.ne120_t12.sehires38.003.sunway.CN_OFF.pop.h.MOCsig.208301-208312.nc at Mon Mar 13 15:18:05 2023
# started MOC calculations Mon Mar 13 15:18:07 2023
# wrote /glade/scratch/tking/MOCsig/B.E.13.BRCP85C5CN.ne120_t12.sehires38.003.sunway.CN_OFF.pop.h.MOCsig.208401-208412.nc at Mon Mar 13 15:20:39 2023
# started MOC calculations Mon Mar 13 15:20:41 2023
# wrote /glade/scratch/tking/MOCsig/B.E.13.BRCP85C5CN.ne120_t12.sehires38.003.sunway.CN_OFF.pop.h.MOCsig.208501-208512.nc at Mon Mar 13 15:23:12 2023
# started MOC calculations Mon Mar 13 15:23:14 2023
# wrote /glade/scratch/tking/MOCsig/B.E.13.BRCP85C5CN.ne120_t12.sehires38.003.sunway.CN_OFF.pop.h.MOCsig.208601-208612.nc at Mon Mar 13 15:25:47 2023
# started MOC calculations Mon Mar 13 15:25:48 2023
# wrote /glade/scratch/tking/MOCsig/B.E.13.BRCP85C5CN.ne120_t12.sehires38.003.sunway.CN_OFF.pop.h.MOCsig.208701-208712.nc at Mon Mar 13 15:28:15 2023
# started MOC calculations Mon Mar 13 15:28:17 2023
# wrote /glade/scratch/tking/MOCsig/B.E.13.BRCP85C5CN.ne120_t12.sehires38.003.sunway.CN_OFF.pop.h.MOCsig.208801-208812.nc at Mon Mar 13 15:30:46 2023
# started MOC calculations Mon Mar 13 15:30:48 2023
# wrote /glade/scratch/tking/MOCsig/B.E.13.BRCP85C5CN.ne120_t12.sehires38.003.sunway.CN_OFF.pop.h.MOCsig.208901-208912.nc at Mon Mar 13 15:33:16 2023
# started MOC calculations Mon Mar 13 15:33:18 2023
# wrote /glade/scratch/tking/MOCsig/B.E.13.BRCP85C5CN.ne120_t12.sehires38.003.sunway.CN_OFF.pop.h.MOCsig.209001-209012.nc at Mon Mar 13 15:35:46 2023
# started MOC calculations Mon Mar 13 15:35:48 2023
# wrote /glade/scratch/tking/MOCsig/B.E.13.BRCP85C5CN.ne120_t12.sehires38.003.sunway.CN_OFF.pop.h.MOCsig.209101-209112.nc at Mon Mar 13 15:38:21 2023
# started MOC calculations Mon Mar 13 15:38:22 2023
# wrote /glade/scratch/tking/MOCsig/B.E.13.BRCP85C5CN.ne120_t12.sehires38.003.sunway.CN_OFF.pop.h.MOCsig.209201-209212.nc at Mon Mar 13 15:40:51 2023
# started MOC calculations Mon Mar 13 15:40:52 2023
# wrote /glade/scratch/tking/MOCsig/B.E.13.BRCP85C5CN.ne120_t12.sehires38.003.sunway.CN_OFF.pop.h.MOCsig.209301-209312.nc at Mon Mar 13 15:43:23 2023
# started MOC calculations Mon Mar 13 15:43:25 2023
# wrote /glade/scratch/tking/MOCsig/B.E.13.BRCP85C5CN.ne120_t12.sehires38.003.sunway.CN_OFF.pop.h.MOCsig.209401-209412.nc at Mon Mar 13 15:45:57 2023
# started MOC calculations Mon Mar 13 15:45:59 2023
# wrote /glade/scratch/tking/MOCsig/B.E.13.BRCP85C5CN.ne120_t12.sehires38.003.sunway.CN_OFF.pop.h.MOCsig.209501-209512.nc at Mon Mar 13 15:48:29 2023
# started MOC calculations Mon Mar 13 15:48:31 2023
# wrote /glade/scratch/tking/MOCsig/B.E.13.BRCP85C5CN.ne120_t12.sehires38.003.sunway.CN_OFF.pop.h.MOCsig.209601-209612.nc at Mon Mar 13 15:51:02 2023
# started MOC calculations Mon Mar 13 15:51:04 2023
# wrote /glade/scratch/tking/MOCsig/B.E.13.BRCP85C5CN.ne120_t12.sehires38.003.sunway.CN_OFF.pop.h.MOCsig.209701-209712.nc at Mon Mar 13 15:53:38 2023
# started MOC calculations Mon Mar 13 15:53:39 2023
# wrote /glade/scratch/tking/MOCsig/B.E.13.BRCP85C5CN.ne120_t12.sehires38.003.sunway.CN_OFF.pop.h.MOCsig.209801-209812.nc at Mon Mar 13 15:56:10 2023
# started MOC calculations Mon Mar 13 15:56:12 2023
# wrote /glade/scratch/tking/MOCsig/B.E.13.BRCP85C5CN.ne120_t12.sehires38.003.sunway.CN_OFF.pop.h.MOCsig.209901-209912.nc at Mon Mar 13 15:58:43 2023
# started MOC calculations Mon Mar 13 15:58:45 2023
# wrote /glade/scratch/tking/MOCsig/B.E.13.BRCP85C5CN.ne120_t12.sehires38.003.sunway.CN_OFF.pop.h.MOCsig.210001-210012.nc at Mon Mar 13 16:01:18 2023
# started MOC calculations Mon Mar 13 16:01:19 2023
# wrote /glade/scratch/tking/MOCsig/B.E.13.BRCP85C5CN.ne120_t12.sehires38.003.sunway.CN_OFF.pop.h.MOCsig.210101-210112.nc at Mon Mar 13 16:03:50 2023
